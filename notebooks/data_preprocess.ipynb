# %%
# Out:
# Libraries imported successfully

# %%
# Out:
# Loading raw data for analysis...
# Loaded 500,000 records...
# Loaded 1,000,000 records...
# Loaded 1,500,000 records...
# Data loading complete! Total records: 1,969,102
# DataFrame shape: (1969102, 5)
# Columns: ['timestamp', 'user_id', 'event_type', 'movie_id', 'minute']
#
# Sample data:
#              timestamp user_id event_type                   movie_id  minute
# 0  2025-09-26T22:17:51   60121      watch               trances+1981      31
# 1  2025-09-26T22:17:51   59184      watch  the+science+of+sleep+2006      42
# 2  2025-09-26T22:17:51   69182      watch       the+dark+knight+2008      23

# %%
# Out:
# === Analyzing Data for Temporal Split ===
# Unique user-movie interactions: 1,969,102
#
# Time range in data:
# Earliest: 2025-09-26 22:17:51
# Latest: 2025-09-27 01:05:01
# Time span: 0 days 02:47:10
#
# Basic statistics:
# Total users: 27,591
# Total movies: 12,516
# Total interactions: 1,969,102
#
# User interaction distribution:
# Mean interactions per user: 71.37
# Median interactions per user: 73.00
# Max interactions per user: 292
# Min interactions per user: 1

# %%
# Out:
# === Performing Temporal Split ===
# Time-based split:
# Training period: 2025-09-26 22:17:51 to 2025-09-27 00:31:35
# Validation period: 2025-09-27 00:31:35 to 2025-09-27 01:05:01
#
# Split results:
# Train interactions: 1,588,619
# Validation interactions: 380,483
# Split ratio: 19.3% validation
#
# Final datasets:
# Train set: 1,588,619 interactions, 25,262 users, 11,557 movies
# Validation set: 380,483 interactions, 14,927 users, 7,495 movies
#
# User overlap analysis:
# Users in both train and validation: 12,598
# New users only in validation (cold start): 2,329
# Total unique users: 27,591

# %%
# Out:
# === Creating Train and Validation JSONL Files ===
# Train pairs: 26,443
# Validation pairs: 14,991
# Writing JSONL files...
# ✓ Train JSONL created: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/train_watch_segments.jsonl
#   - 1,912,379 segment records
# ✓ Validation JSONL created: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/val_watch_segments.jsonl
#   - 56,723 segment records
#
# Verification:
# Original total segments: 1,969,102
# Train + Val segments: 1,969,102
# Match: True

# %%
# Out:
# === Processing Training Data for Implicit ===
# Training matrix will be: 25,262 users × 11,557 movies
# Training matrix shape: (25262, 11557)
# Non-zero elements: 26,443
# Training matrix sparsity: 99.9909%

# %%
# Out:
# === Saving Files ===
# ✓ Training matrix saved: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/train_matrix.npz
# ✓ User mappings saved: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/user_mappings.pkl
# ✓ Movie mappings saved: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/movie_mappings.pkl
# ✓ Split metadata saved: /home/lenghanz/group-project-f25-shrekommender-system/data/processed/split_metadata.pkl
#
# ...
# ✅ DATA PREPROCESSING COMPLETE!
# ...
# Output files in: /home/lenghanz/group-project-f25-shrekommender-system/data/processed
# 1. train_watch_segments.jsonl - Training segment data
# 2. val_watch_segments.jsonl - Validation segment data
# 3. train_matrix.npz - Training matrix for implicit
# 4. user_mappings.pkl - User ID mappings
# 5. movie_mappings.pkl - Movie ID mappings
# 6. split_metadata.pkl - Split statistics
#
# Key improvements with temporal split:
# • Validation set: 380,483 interactions (much larger!)
# ...
